# %%
#Calculating the Average of five Entered number
A=int(input("Enter a number"))
B=int(input("Enter a number"))
C=int(input("Enter a number"))
D=int(input("Enter a number"))
E=int(input("Enter a number"))
av=(A+B+C+D+E)/5
print("Average is",av)
# Out:
# Enter a number5
# Enter a number5
# Enter a number5
# Enter a number2
# Enter a number3
# Average is 4.0
