# %%
P=int(input("Enter Principle"))
R=int(input("Enter Rate of Intrest"))
T=int(input("Enter Time in Years"))
CI=P*(1+R/100)**T
A=P+CI
print("Compound Intrest is",CI ,"Amount is",A)
# Out:
# Enter Principle4000
# Enter Rate of Intrest5
# Enter Time in Years3
# Compound Intrest is 4630.500000000001 Amount is 8630.5
