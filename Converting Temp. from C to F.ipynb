# %%
c=float(input("Enter 1 to convert temprature in FAHRENHIET to CELSIUS and 2 to convert temprature in CELSIUS to FAHRENHIET"))
if(c==1):
    F=float(input("Enter temprature in Fahrenhiet "))
    C=5/9*(F-32)
    print("Temprature in Celsius is ",C)
if(c==2):
    C=float(input("Enter temprature in Celsius "))
    F=(9/5*C)+32
    print("Temprature in Fahrenhiet is ",F)
# Out:
# Enter 1 to convert temprature in FAHRENHIET to CELSIUS and 2 to convert temprature in CELSIUS to FAHRENHIET2
# Enter temprature in Celsius 0
# Temprature in Fahrenhiet is  32.0
