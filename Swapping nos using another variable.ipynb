# %%
#Swapping Numbers using another variable
A=int(input("Enter a number"))
B=int(input("Enter a number"))
C=A
A=B
B=C
print("Swapped nos are", A, B)
# Out:
# Enter a number6
# Enter a number9
# Swapped nos are 9 6
