# %%
p=int(input("Enter Priciple"))
r=int(input("Enter Rate of Intrest"))
t=int(input("Enter Time"))
SI=(p*r*t)/100
print("Simple Intrest is",SI)
# Out:
# Enter Priciple5
# Enter Rate of Intrest5
# Enter Time5
# Simple Intrest is 1.25
