# %%
N=float(input("Choose if you want to calculate Area or Perimeter of a Square (1 for calculating Perimeter and 2 for calculating Area)"))
if(N==1):
    L=float(input("Enter the length of a side of a square"))
    P=4*L
    print("Perimeter of the square is",P)
if(N==2):
    L=float(input("Enter the length of a side of a square"))
    A=L*L
    print("Area of the square is",A)
if(N==3):
    L=float(input("Enter the length of a Rectangle"))
    B=float(input("Enter the width of a Rectangle"))
    A=L*B
    print("Area of the Rebtangle is",A)
if(N==4):
    L=float(input("Enter the length of a side of a Rectangle"))
    B=float(input("Enter the width of a Rectangle"))
    P=2*(L+B)
    print("Perimeter of the Rectangle is",A)
if(N==5):
    R=float(input("Enter the Radius of a Circle"))
    A=R*R*22/7
    print("Area of the Circle is",A)
if(N==6):
     R=float(input("Enter the Radius of a Circle"))
     A=2*R*22/7
     print("Perimeter of the Circle is",A)
