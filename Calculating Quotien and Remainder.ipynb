# %%
D=int(input("Enter Dividend"))
Di=int(input("Enter Divisor"))
Q=D//Di
R=D%Di
print("Quotient is",Q,"and Remainder is",R)
# Out:
# Enter Dividend100
# Enter Divisor100
# Quotient is 1 and Remainder is 0
